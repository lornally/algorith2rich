# %%
# https://huggingface.co/docs/diffusers/optimization/mps
# https://pytorch.org/get-started/locally/
# %conda install pytorch torchvision torchaudio -c pytorch
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-arm64::urllib3==1.26.14=py310hca03da5_0
#   - pytorch-nightly/osx-arm64::torchvision==0.16.0.dev20230316=py310_cpu
#   - defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0
#   - pytorch-nightly/osx-arm64::torchaudio==2.0.0.dev20230317=py310_cpu
#   - defaults/osx-arm64::conda==23.1.0=py310hca03da5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/bergman/miniconda3
#
#   added / updated specs:
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pytorch-2.0.0              |         py3.10_0        47.1 MB  pytorch
#     requests-2.28.1            |  py310hca03da5_1         102 KB
#     torchaudio-2.0.0           |        py310_cpu         6.5 MB  pytorch
#     torchvision-0.15.0         |        py310_cpu         6.4 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        60.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   idna               pkgs/main/osx-arm64::idna-3.4-py310hca03da5_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.23.5-py310haf87e8b_0
#   requests           pkgs/main/osx-arm64::requests-2.28.1-py310hca03da5_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> pkgs/main::ca-certificates-2023.01.10-hca03da5_0
#   torchaudio         pytorch-nightly::torchaudio-2.0.0.dev~ --> pytorch::torchaudio-2.0.0-py310_cpu
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/osx-arm64::certifi-2022.12.7-py310hca03da5_0
#   openssl            conda-forge::openssl-1.1.1t-h03a7124_0 --> pkgs/main::openssl-1.1.1t-h1a28f6b_0
#   pytorch            pytorch-nightly::pytorch-2.1.0.dev202~ --> pytorch::pytorch-2.0.0-py3.10_0
#   torchvision        pytorch-nightly::torchvision-0.16.0.d~ --> pytorch::torchvision-0.15.0-py310_cpu
#
#
#
# Downloading and Extracting Packages
# torchaudio-2.0.0     | 6.5 MB    |                                       |   0%
# pytorch-2.0.0        | 47.1 MB   |                                       |   0%
#
# torchvision-0.15.0   | 6.4 MB    |                                       |   0%
#
#
# requests-2.28.1      | 102 KB    |                                       |   0%
#
#
# torchaudio-2.0.0     | 6.5 MB    |                                       |   0%
# pytorch-2.0.0        | 47.1 MB   |                                       |   0%
#
# torchvision-0.15.0   | 6.4 MB    |                                       |   0%
#
#
# requests-2.28.1      | 102 KB    | ##################################### | 100%
#
#
# torchaudio-2.0.0     | 6.5 MB    | #1                                    |   3%
# pytorch-2.0.0        | 47.1 MB   | 1                                     |   0%
#
# torchvision-0.15.0   | 6.4 MB    | 9                                     |   3%
# torchaudio-2.0.0     | 6.5 MB    | #7                                    |   5%
#
# torchvision-0.15.0   | 6.4 MB    | ##6                                   |   7%
# torchaudio-2.0.0     | 6.5 MB    | ###6                                  |  10%
#
# torchvision-0.15.0   | 6.4 MB    | ###5                                  |  10%
# pytorch-2.0.0        | 47.1 MB   | 5                                     |   1%
#
# torchaudio-2.0.0     | 6.5 MB    | ####7                                 |  13%
# pytorch-2.0.0        | 47.1 MB   | 6                                     |   2%
#
# torchvision-0.15.0   | 6.4 MB    | #####                                 |  14%
# torchaudio-2.0.0     | 6.5 MB    | #####5                                |  15%
# pytorch-2.0.0        | 47.1 MB   | 8                                     |   2%
#
# torchaudio-2.0.0     | 6.5 MB    | ######3                               |  17%
# pytorch-2.0.0        | 47.1 MB   | 9                                     |   2%
#
# torchaudio-2.0.0     | 6.5 MB    | ########2                             |  22%
# pytorch-2.0.0        | 47.1 MB   | #1                                    |   3%
#
# torchvision-0.15.0   | 6.4 MB    | ########                              |  22%
# pytorch-2.0.0        | 47.1 MB   | #1                                    |   3%
# pytorch-2.0.0        | 47.1 MB   | #2                                    |   3%
# pytorch-2.0.0        | 47.1 MB   | #3                                    |   4%
# torchaudio-2.0.0     | 6.5 MB    | ########9                             |  24%
# torchaudio-2.0.0     | 6.5 MB    | #########4                            |  26%
# torchaudio-2.0.0     | 6.5 MB    | ##########2                           |  28%
# pytorch-2.0.0        | 47.1 MB   | ##                                    |   6%
#
# torchaudio-2.0.0     | 6.5 MB    | ##########8                           |  29%
# torchaudio-2.0.0     | 6.5 MB    | ###########3                          |  31%
# torchaudio-2.0.0     | 6.5 MB    | ###########8                          |  32%
# torchaudio-2.0.0     | 6.5 MB    | ############1                         |  33%
# torchaudio-2.0.0     | 6.5 MB    | ############6                         |  34%
#
# torchaudio-2.0.0     | 6.5 MB    | #############2                        |  36%
# pytorch-2.0.0        | 47.1 MB   | ##4                                   |   7%
#
# torchvision-0.15.0   | 6.4 MB    | #########8                            |  27%
# pytorch-2.0.0        | 47.1 MB   | ##5                                   |   7%
#
# torchaudio-2.0.0     | 6.5 MB    | #############6                        |  37%
# pytorch-2.0.0        | 47.1 MB   | ##6                                   |   7%
#
# torchvision-0.15.0   | 6.4 MB    | ##########7                           |  29%
# pytorch-2.0.0        | 47.1 MB   | ##6                                   |   7%
#
# torchvision-0.15.0   | 6.4 MB    | ###########5                          |  31%
# torchaudio-2.0.0     | 6.5 MB    | ##############                        |  38%
#
# torchvision-0.15.0   | 6.4 MB    | ############                          |  33%
# pytorch-2.0.0        | 47.1 MB   | ##8                                   |   8%
# pytorch-2.0.0        | 47.1 MB   | ##9                                   |   8%
#
# torchaudio-2.0.0     | 6.5 MB    | ##############4                       |  39%
# pytorch-2.0.0        | 47.1 MB   | ##9                                   |   8%
#
# torchaudio-2.0.0     | 6.5 MB    | ##############9                       |  40%
# pytorch-2.0.0        | 47.1 MB   | ###                                   |   8%
#
# torchaudio-2.0.0     | 6.5 MB    | ###############1                      |  41%
# pytorch-2.0.0        | 47.1 MB   | ###1                                  |   8%
#
# torchaudio-2.0.0     | 6.5 MB    | ###############8                      |  43%
# torchaudio-2.0.0     | 6.5 MB    | ################3                     |  44%
#
# torchvision-0.15.0   | 6.4 MB    | ###############8                      |  43%
# torchaudio-2.0.0     | 6.5 MB    | ################8                     |  46%
#
# torchvision-0.15.0   | 6.4 MB    | ################4                     |  44%
# torchaudio-2.0.0     | 6.5 MB    | #################2                    |  47%
#
# torchvision-0.15.0   | 6.4 MB    | ################9                     |  46%
# torchaudio-2.0.0     | 6.5 MB    | #################9                    |  48%
#
# torchvision-0.15.0   | 6.4 MB    | #################5                    |  47%
#
# torchaudio-2.0.0     | 6.5 MB    | ##################3                   |  50%
# torchaudio-2.0.0     | 6.5 MB    | ##################9                   |  51%
#
# torchvision-0.15.0   | 6.4 MB    | ##################6                   |  50%
# pytorch-2.0.0        | 47.1 MB   | ###6                                  |  10%
#
# torchvision-0.15.0   | 6.4 MB    | ###################4                  |  52%
# torchaudio-2.0.0     | 6.5 MB    | ###################7                  |  53%
# torchaudio-2.0.0     | 6.5 MB    | ####################2                 |  55%
#
# torchvision-0.15.0   | 6.4 MB    | ###################9                  |  54%
# pytorch-2.0.0        | 47.1 MB   | ###8                                  |  10%
#
# torchaudio-2.0.0     | 6.5 MB    | ####################9                 |  57%
# pytorch-2.0.0        | 47.1 MB   | ###9                                  |  11%
#
# torchvision-0.15.0   | 6.4 MB    | #####################1                |  57%
# torchaudio-2.0.0     | 6.5 MB    | #####################3                |  58%
#
# torchaudio-2.0.0     | 6.5 MB    | ######################2               |  60%
# pytorch-2.0.0        | 47.1 MB   | ####                                  |  11%
#
# torchvision-0.15.0   | 6.4 MB    | ######################2               |  60%
# pytorch-2.0.0        | 47.1 MB   | ####1                                 |  11%
# pytorch-2.0.0        | 47.1 MB   | ####1                                 |  11%
# torchaudio-2.0.0     | 6.5 MB    | ######################8               |  62%
# pytorch-2.0.0        | 47.1 MB   | ####3                                 |  12%
#
# torchaudio-2.0.0     | 6.5 MB    | #######################5              |  64%
# pytorch-2.0.0        | 47.1 MB   | ####4                                 |  12%
#
# torchaudio-2.0.0     | 6.5 MB    | ########################1             |  65%
#
# torchvision-0.15.0   | 6.4 MB    | #######################3              |  63%
# pytorch-2.0.0        | 47.1 MB   | ####5                                 |  12%
#
# torchaudio-2.0.0     | 6.5 MB    | ########################4             |  66%
# pytorch-2.0.0        | 47.1 MB   | ####6                                 |  13%
#
# torchaudio-2.0.0     | 6.5 MB    | ########################8             |  67%
# pytorch-2.0.0        | 47.1 MB   | ####6                                 |  13%
#
# torchaudio-2.0.0     | 6.5 MB    | #########################3            |  69%
# torchaudio-2.0.0     | 6.5 MB    | #########################7            |  70%
#
# torchvision-0.15.0   | 6.4 MB    | ########################9             |  68%
# torchaudio-2.0.0     | 6.5 MB    | ##########################            |  70%
#
# torchvision-0.15.0   | 6.4 MB    | #########################3            |  69%
# pytorch-2.0.0        | 47.1 MB   | ####9                                 |  13%
#
# torchaudio-2.0.0     | 6.5 MB    | ##########################4           |  71%
# pytorch-2.0.0        | 47.1 MB   | ####9                                 |  13%
#
# torchaudio-2.0.0     | 6.5 MB    | ##########################8           |  73%
# torchaudio-2.0.0     | 6.5 MB    | ###########################5          |  75%
# pytorch-2.0.0        | 47.1 MB   | #####                                 |  14%
#
# torchvision-0.15.0   | 6.4 MB    | ###########################           |  73%
#
# torchaudio-2.0.0     | 6.5 MB    | ############################4         |  77%
# pytorch-2.0.0        | 47.1 MB   | #####2                                |  14%
#
# torchaudio-2.0.0     | 6.5 MB    | #############################         |  78%
# torchaudio-2.0.0     | 6.5 MB    | #############################5        |  80%
# pytorch-2.0.0        | 47.1 MB   | #####5                                |  15%
#
# torchvision-0.15.0   | 6.4 MB    | ############################9         |  78%
#
# torchvision-0.15.0   | 6.4 MB    | #############################4        |  79%
#
# torchvision-0.15.0   | 6.4 MB    | #############################7        |  80%
# pytorch-2.0.0        | 47.1 MB   | #####5                                |  15%
#
# torchvision-0.15.0   | 6.4 MB    | ##############################3       |  82%
# torchaudio-2.0.0     | 6.5 MB    | ##############################        |  81%
#
# torchvision-0.15.0   | 6.4 MB    | ###############################       |  84%
# pytorch-2.0.0        | 47.1 MB   | #####7                                |  16%
#
# torchvision-0.15.0   | 6.4 MB    | ###############################4      |  85%
# torchaudio-2.0.0     | 6.5 MB    | ##############################4       |  82%
#
# torchvision-0.15.0   | 6.4 MB    | ################################      |  87%
# torchaudio-2.0.0     | 6.5 MB    | ###############################       |  84%
#
# torchvision-0.15.0   | 6.4 MB    | ################################4     |  88%
# torchaudio-2.0.0     | 6.5 MB    | ###############################5      |  85%
# pytorch-2.0.0        | 47.1 MB   | ######                                |  16%
#
# torchaudio-2.0.0     | 6.5 MB    | ##################################5   |  93%
# pytorch-2.0.0        | 47.1 MB   | ######1                               |  17%
#
# torchvision-0.15.0   | 6.4 MB    | #################################4    |  90%
# pytorch-2.0.0        | 47.1 MB   | ######2                               |  17%
#
# torchaudio-2.0.0     | 6.5 MB    | ##################################9   |  95%
#
# torchaudio-2.0.0     | 6.5 MB    | ###################################4  |  96%
# pytorch-2.0.0        | 47.1 MB   | ######3                               |  17%
# pytorch-2.0.0        | 47.1 MB   | ######3                               |  17%
#
# torchaudio-2.0.0     | 6.5 MB    | ###################################7  |  97%
#
# torchaudio-2.0.0     | 6.5 MB    | ####################################4 |  99%
# pytorch-2.0.0        | 47.1 MB   | ######4                               |  18%
# pytorch-2.0.0        | 47.1 MB   | ######7                               |  18%
# pytorch-2.0.0        | 47.1 MB   | ######8                               |  18%
# pytorch-2.0.0        | 47.1 MB   | ######8                               |  19%
# pytorch-2.0.0        | 47.1 MB   | #######                               |  19%
#
# torchvision-0.15.0   | 6.4 MB    | ##################################### | 100%
#
# torchaudio-2.0.0     | 6.5 MB    | ##################################### | 100%
# pytorch-2.0.0        | 47.1 MB   | #######2                              |  20%
# pytorch-2.0.0        | 47.1 MB   | #######3                              |  20%
# pytorch-2.0.0        | 47.1 MB   | #######4                              |  20%
# pytorch-2.0.0        | 47.1 MB   | #######6                              |  21%
# pytorch-2.0.0        | 47.1 MB   | #######9                              |  21%
# pytorch-2.0.0        | 47.1 MB   | ########                              |  22%
# pytorch-2.0.0        | 47.1 MB   | ########2                             |  22%
# pytorch-2.0.0        | 47.1 MB   | ########4                             |  23%
# pytorch-2.0.0        | 47.1 MB   | ########6                             |  23%
# pytorch-2.0.0        | 47.1 MB   | ########7                             |  24%
# pytorch-2.0.0        | 47.1 MB   | ########9                             |  24%
# pytorch-2.0.0        | 47.1 MB   | #########                             |  24%
# pytorch-2.0.0        | 47.1 MB   | #########2                            |  25%
# pytorch-2.0.0        | 47.1 MB   | #########3                            |  25%
# pytorch-2.0.0        | 47.1 MB   | #########6                            |  26%
# pytorch-2.0.0        | 47.1 MB   | ##########                            |  27%
# pytorch-2.0.0        | 47.1 MB   | ##########2                           |  28%
# pytorch-2.0.0        | 47.1 MB   | ##########4                           |  28%
# pytorch-2.0.0        | 47.1 MB   | ##########6                           |  29%
# pytorch-2.0.0        | 47.1 MB   | ##########7                           |  29%
# pytorch-2.0.0        | 47.1 MB   | ##########9                           |  30%
# pytorch-2.0.0        | 47.1 MB   | ###########1                          |  30%
# pytorch-2.0.0        | 47.1 MB   | ###########2                          |  30%
# pytorch-2.0.0        | 47.1 MB   | ###########3                          |  31%
# pytorch-2.0.0        | 47.1 MB   | ###########5                          |  31%
# pytorch-2.0.0        | 47.1 MB   | ###########6                          |  31%
# pytorch-2.0.0        | 47.1 MB   | ###########7                          |  32%
# pytorch-2.0.0        | 47.1 MB   | ###########8                          |  32%
# pytorch-2.0.0        | 47.1 MB   | ############                          |  33%
# pytorch-2.0.0        | 47.1 MB   | ############2                         |  33%
# pytorch-2.0.0        | 47.1 MB   | ############4                         |  34%
# pytorch-2.0.0        | 47.1 MB   | ############5                         |  34%
# pytorch-2.0.0        | 47.1 MB   | ############7                         |  34%
# pytorch-2.0.0        | 47.1 MB   | ############9                         |  35%
# pytorch-2.0.0        | 47.1 MB   | #############1                        |  36%
# pytorch-2.0.0        | 47.1 MB   | #############4                        |  36%
# pytorch-2.0.0        | 47.1 MB   | #############6                        |  37%
# pytorch-2.0.0        | 47.1 MB   | #############7                        |  37%
# pytorch-2.0.0        | 47.1 MB   | ##############                        |  38%
# pytorch-2.0.0        | 47.1 MB   | ##############2                       |  38%
# pytorch-2.0.0        | 47.1 MB   | ##############3                       |  39%
# pytorch-2.0.0        | 47.1 MB   | ##############5                       |  39%
# pytorch-2.0.0        | 47.1 MB   | ##############6                       |  40%
# pytorch-2.0.0        | 47.1 MB   | ##############8                       |  40%
# pytorch-2.0.0        | 47.1 MB   | ##############9                       |  40%
# pytorch-2.0.0        | 47.1 MB   | ###############1                      |  41%
# pytorch-2.0.0        | 47.1 MB   | ###############3                      |  41%
# pytorch-2.0.0        | 47.1 MB   | ###############6                      |  42%
# pytorch-2.0.0        | 47.1 MB   | ###############7                      |  43%
# pytorch-2.0.0        | 47.1 MB   | ###############9                      |  43%
# pytorch-2.0.0        | 47.1 MB   | ################2                     |  44%
# pytorch-2.0.0        | 47.1 MB   | ################5                     |  45%
# pytorch-2.0.0        | 47.1 MB   | ################7                     |  45%
# pytorch-2.0.0        | 47.1 MB   | #################                     |  46%
# pytorch-2.0.0        | 47.1 MB   | #################2                    |  47%
# pytorch-2.0.0        | 47.1 MB   | #################4                    |  47%
# pytorch-2.0.0        | 47.1 MB   | #################6                    |  48%
# pytorch-2.0.0        | 47.1 MB   | #################7                    |  48%
# pytorch-2.0.0        | 47.1 MB   | #################9                    |  49%
# pytorch-2.0.0        | 47.1 MB   | ##################2                   |  49%
# pytorch-2.0.0        | 47.1 MB   | ##################3                   |  50%
# pytorch-2.0.0        | 47.1 MB   | ##################5                   |  50%
# pytorch-2.0.0        | 47.1 MB   | ##################7                   |  51%
# pytorch-2.0.0        | 47.1 MB   | ##################8                   |  51%
# pytorch-2.0.0        | 47.1 MB   | ###################                   |  51%
# pytorch-2.0.0        | 47.1 MB   | ###################2                  |  52%
# pytorch-2.0.0        | 47.1 MB   | ###################3                  |  52%
# pytorch-2.0.0        | 47.1 MB   | ###################5                  |  53%
# pytorch-2.0.0        | 47.1 MB   | ###################7                  |  53%
# pytorch-2.0.0        | 47.1 MB   | ###################9                  |  54%
# pytorch-2.0.0        | 47.1 MB   | ####################1                 |  54%
# pytorch-2.0.0        | 47.1 MB   | ####################2                 |  55%
# pytorch-2.0.0        | 47.1 MB   | ####################4                 |  55%
# pytorch-2.0.0        | 47.1 MB   | ####################5                 |  56%
# pytorch-2.0.0        | 47.1 MB   | ####################8                 |  56%
# pytorch-2.0.0        | 47.1 MB   | #####################                 |  57%
# pytorch-2.0.0        | 47.1 MB   | #####################2                |  58%
# pytorch-2.0.0        | 47.1 MB   | #####################5                |  58%
# pytorch-2.0.0        | 47.1 MB   | #####################7                |  59%
# pytorch-2.0.0        | 47.1 MB   | #####################9                |  59%
# pytorch-2.0.0        | 47.1 MB   | ######################                |  60%
# pytorch-2.0.0        | 47.1 MB   | ######################1               |  60%
# pytorch-2.0.0        | 47.1 MB   | ######################3               |  60%
# pytorch-2.0.0        | 47.1 MB   | ######################4               |  61%
# pytorch-2.0.0        | 47.1 MB   | ######################5               |  61%
# pytorch-2.0.0        | 47.1 MB   | ######################6               |  61%
# pytorch-2.0.0        | 47.1 MB   | ######################8               |  62%
# pytorch-2.0.0        | 47.1 MB   | #######################2              |  63%
# pytorch-2.0.0        | 47.1 MB   | #######################4              |  63%
# pytorch-2.0.0        | 47.1 MB   | #######################6              |  64%
# pytorch-2.0.0        | 47.1 MB   | #######################8              |  64%
# pytorch-2.0.0        | 47.1 MB   | #######################9              |  65%
# pytorch-2.0.0        | 47.1 MB   | ########################1             |  65%
# pytorch-2.0.0        | 47.1 MB   | ########################3             |  66%
# pytorch-2.0.0        | 47.1 MB   | ########################4             |  66%
# pytorch-2.0.0        | 47.1 MB   | ########################6             |  67%
# pytorch-2.0.0        | 47.1 MB   | ########################8             |  67%
# pytorch-2.0.0        | 47.1 MB   | #########################             |  68%
# pytorch-2.0.0        | 47.1 MB   | #########################2            |  68%
# pytorch-2.0.0        | 47.1 MB   | #########################4            |  69%
# pytorch-2.0.0        | 47.1 MB   | #########################8            |  70%
# pytorch-2.0.0        | 47.1 MB   | ##########################            |  70%
# pytorch-2.0.0        | 47.1 MB   | ##########################2           |  71%
# pytorch-2.0.0        | 47.1 MB   | ##########################5           |  72%
# pytorch-2.0.0        | 47.1 MB   | ##########################8           |  72%
# pytorch-2.0.0        | 47.1 MB   | ###########################           |  73%
# pytorch-2.0.0        | 47.1 MB   | ###########################2          |  74%
# pytorch-2.0.0        | 47.1 MB   | ###########################4          |  74%
# pytorch-2.0.0        | 47.1 MB   | ###########################5          |  75%
# pytorch-2.0.0        | 47.1 MB   | ###########################7          |  75%
# pytorch-2.0.0        | 47.1 MB   | ###########################8          |  75%
# pytorch-2.0.0        | 47.1 MB   | ###########################9          |  75%
# pytorch-2.0.0        | 47.1 MB   | ############################          |  76%
# pytorch-2.0.0        | 47.1 MB   | ############################1         |  76%
# pytorch-2.0.0        | 47.1 MB   | ############################2         |  76%
# pytorch-2.0.0        | 47.1 MB   | ############################4         |  77%
# pytorch-2.0.0        | 47.1 MB   | ############################5         |  77%
# pytorch-2.0.0        | 47.1 MB   | ############################7         |  78%
# pytorch-2.0.0        | 47.1 MB   | ############################9         |  78%
# pytorch-2.0.0        | 47.1 MB   | #############################1        |  79%
# pytorch-2.0.0        | 47.1 MB   | #############################2        |  79%
# pytorch-2.0.0        | 47.1 MB   | #############################4        |  80%
# pytorch-2.0.0        | 47.1 MB   | #############################7        |  80%
# pytorch-2.0.0        | 47.1 MB   | ##############################        |  81%
# pytorch-2.0.0        | 47.1 MB   | ##############################2       |  82%
# pytorch-2.0.0        | 47.1 MB   | ##############################4       |  82%
# pytorch-2.0.0        | 47.1 MB   | ##############################6       |  83%
# pytorch-2.0.0        | 47.1 MB   | ##############################8       |  83%
# pytorch-2.0.0        | 47.1 MB   | ###############################       |  84%
# pytorch-2.0.0        | 47.1 MB   | ###############################2      |  84%
# pytorch-2.0.0        | 47.1 MB   | ###############################3      |  85%
# pytorch-2.0.0        | 47.1 MB   | ###############################4      |  85%
# pytorch-2.0.0        | 47.1 MB   | ###############################5      |  85%
# pytorch-2.0.0        | 47.1 MB   | ###############################7      |  86%
# pytorch-2.0.0        | 47.1 MB   | ###############################9      |  86%
# pytorch-2.0.0        | 47.1 MB   | ################################1     |  87%
# pytorch-2.0.0        | 47.1 MB   | ################################3     |  88%
# pytorch-2.0.0        | 47.1 MB   | ################################5     |  88%
# pytorch-2.0.0        | 47.1 MB   | ################################7     |  89%
# pytorch-2.0.0        | 47.1 MB   | ################################9     |  89%
# pytorch-2.0.0        | 47.1 MB   | #################################     |  89%
# pytorch-2.0.0        | 47.1 MB   | #################################2    |  90%
# pytorch-2.0.0        | 47.1 MB   | #################################3    |  90%
# pytorch-2.0.0        | 47.1 MB   | #################################4    |  91%
# pytorch-2.0.0        | 47.1 MB   | #################################6    |  91%
# pytorch-2.0.0        | 47.1 MB   | #################################8    |  92%
# pytorch-2.0.0        | 47.1 MB   | ##################################    |  92%
# pytorch-2.0.0        | 47.1 MB   | ##################################3   |  93%
# pytorch-2.0.0        | 47.1 MB   | ##################################6   |  94%
# pytorch-2.0.0        | 47.1 MB   | ##################################7   |  94%
# pytorch-2.0.0        | 47.1 MB   | ##################################9   |  94%
# pytorch-2.0.0        | 47.1 MB   | ###################################1  |  95%
# pytorch-2.0.0        | 47.1 MB   | ###################################4  |  96%
# pytorch-2.0.0        | 47.1 MB   | ###################################7  |  97%
# pytorch-2.0.0        | 47.1 MB   | ####################################1 |  98%
# pytorch-2.0.0        | 47.1 MB   | ####################################3 |  98%
# pytorch-2.0.0        | 47.1 MB   | ####################################4 |  99%
# pytorch-2.0.0        | 47.1 MB   | ####################################6 |  99%
# pytorch-2.0.0        | 47.1 MB   | ####################################8 | 100%
# pytorch-2.0.0        | 47.1 MB   | ####################################9 | 100%
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL
import requests
import torch
from io import BytesIO
torch.distributed.is_available()
# Out:
# True

# %%
# %conda install transformers scipy ftfy
# %conda install "ipywidgets>=7,<8"
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - diffusers
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-arm64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-arm64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-arm64::urllib3==1.26.14=py310hca03da5_0
#   - pytorch-nightly/osx-arm64::torchvision==0.16.0.dev20230316=py310_cpu
#   - defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0
#   - pytorch-nightly/osx-arm64::torchaudio==2.0.0.dev20230317=py310_cpu
#   - defaults/osx-arm64::conda==23.1.0=py310hca03da5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/bergman/miniconda3
#
#   added / updated specs:
#     - ftfy
#     - scipy
#     - transformers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appdirs-1.4.4              |     pyhd3eb1b0_0          12 KB
#     ftfy-5.8                   |             py_0          56 KB
#     huggingface_hub-0.10.1     |  py310hca03da5_0         212 KB
#     pooch-1.4.0                |     pyhd3eb1b0_0          41 KB
#     pyyaml-6.0                 |  py310h80987f9_1         164 KB
#     regex-2022.7.9             |  py310h1a28f6b_0         317 KB
#     scipy-1.10.1               |  py310h20cbe94_0        20.7 MB
#     tokenizers-0.11.4          |  py310h5c5695e_1         2.5 MB
#     transformers-4.24.0        |  py310hca03da5_0         4.8 MB
#     typing-extensions-4.4.0    |  py310hca03da5_0           9 KB
#     yaml-0.2.5                 |       h1a28f6b_0          71 KB
#     ------------------------------------------------------------
#                                            Total:        28.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            pkgs/main/noarch::appdirs-1.4.4-pyhd3eb1b0_0
#   ftfy               pkgs/main/noarch::ftfy-5.8-py_0
#   huggingface_hub    pkgs/main/osx-arm64::huggingface_hub-0.10.1-py310hca03da5_0
#   idna               pkgs/main/osx-arm64::idna-3.4-py310hca03da5_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.23.5-py310haf87e8b_0
#   pooch              pkgs/main/noarch::pooch-1.4.0-pyhd3eb1b0_0
#   pyyaml             pkgs/main/osx-arm64::pyyaml-6.0-py310h80987f9_1
#   regex              pkgs/main/osx-arm64::regex-2022.7.9-py310h1a28f6b_0
#   requests           pkgs/main/osx-arm64::requests-2.28.1-py310hca03da5_1
#   scipy              pkgs/main/osx-arm64::scipy-1.10.1-py310h20cbe94_0
#   tokenizers         pkgs/main/osx-arm64::tokenizers-0.11.4-py310h5c5695e_1
#   transformers       pkgs/main/osx-arm64::transformers-4.24.0-py310hca03da5_0
#   typing-extensions  pkgs/main/osx-arm64::typing-extensions-4.4.0-py310hca03da5_0
#   yaml               pkgs/main/osx-arm64::yaml-0.2.5-h1a28f6b_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> pkgs/main::ca-certificates-2023.01.10-hca03da5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/osx-arm64::certifi-2022.12.7-py310hca03da5_0
#   openssl            conda-forge::openssl-1.1.1t-h03a7124_0 --> pkgs/main::openssl-1.1.1t-h1a28f6b_0
#
#
#
# Downloading and Extracting Packages
# ftfy-5.8             | 56 KB     |                                       |   0%
# typing-extensions-4. | 9 KB      |                                       |   0%
#
# pyyaml-6.0           | 164 KB    |                                       |   0%
#
#
# regex-2022.7.9       | 317 KB    |                                       |   0%
#
#
#
# appdirs-1.4.4        | 12 KB     |                                       |   0%
#
#
#
#
# huggingface_hub-0.10 | 212 KB    |                                       |   0%
#
#
#
#
#
# pooch-1.4.0          | 41 KB     |                                       |   0%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   |                                       |   0%
#
#
#
#
#
#
#
# yaml-0.2.5           | 71 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    |                                       |   0%
# ftfy-5.8             | 56 KB     | ##########6                           |  29%
#
#
# regex-2022.7.9       | 317 KB    | #8                                    |   5%
#
# pyyaml-6.0           | 164 KB    | ###6                                  |  10%
#
#
#
# appdirs-1.4.4        | 12 KB     | ##################################### | 100%
# typing-extensions-4. | 9 KB      | ##################################### | 100%
#
#
#
# ftfy-5.8             | 56 KB     | ##################################### | 100%
#
# pyyaml-6.0           | 164 KB    | ##################################### | 100%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   |                                       |   0%
#
#
#
#
#
# pooch-1.4.0          | 41 KB     | ##############4                       |  39%
#
#
#
#
#
# pooch-1.4.0          | 41 KB     | ##################################### | 100%
#
#
# regex-2022.7.9       | 317 KB    | ###########################9          |  76%
#
#
# regex-2022.7.9       | 317 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# yaml-0.2.5           | 71 KB     | ########2                             |  22%
#
#
#
#
#
#
#
# yaml-0.2.5           | 71 KB     | ##################################### | 100%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | 3                                     |   1%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | 7                                     |   2%
#
#
#
#
# huggingface_hub-0.10 | 212 KB    | ##7                                   |   8%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | 1                                     |   0%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | 3                                     |   1%
#
#
#
#
# huggingface_hub-0.10 | 212 KB    | ######################3               |  60%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | 8                                     |   2%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #                                     |   3%
#
#
#
#
# huggingface_hub-0.10 | 212 KB    | #################################4    |  91%
#
#
#
#
# huggingface_hub-0.10 | 212 KB    | ##################################### | 100%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##1                                   |   6%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##6                                   |   7%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | 4                                     |   1%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ####5                                 |  12%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ###1                                  |   8%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ######3                               |  17%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ####7                                 |  13%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ####                                  |  11%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | #############6                        |  37%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ################1                     |  44%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ###################1                  |  52%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ######################7               |  62%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | #########################2            |  68%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ####5                                 |  12%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ###########################7          |  75%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ####9                                 |  13%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | #############################8        |  81%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #####8                                |  16%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ###############################9      |  86%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ######8                               |  19%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | #################################7    |  91%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #######4                              |  20%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #####                                 |  14%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ###################################3  |  95%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ########3                             |  22%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ########9                             |  24%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
# tokenizers-0.11.4    | 2.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #########9                            |  27%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##########5                           |  29%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #####2                                |  14%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ###########4                          |  31%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #####4                                |  15%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #####6                                |  15%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ############7                         |  34%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #####9                                |  16%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #############4                        |  36%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ######3                               |  17%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ######6                               |  18%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ######9                               |  19%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #######1                              |  19%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##############                        |  38%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #######5                              |  20%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##############7                       |  40%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ###############3                      |  42%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ###############8                      |  43%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #######7                              |  21%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ########                              |  22%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ################9                     |  46%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #################8                    |  48%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ########2                             |  22%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##################8                   |  51%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ########4                             |  23%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ########6                             |  23%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ####################                  |  54%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ########8                             |  24%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #####################                 |  57%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ########9                             |  24%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #########1                            |  25%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #####################7                |  59%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #########4                            |  26%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ######################6               |  61%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #########6                            |  26%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #######################5              |  64%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #########8                            |  27%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ########################4             |  66%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##########                            |  27%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #########################             |  68%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##########4                           |  28%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #########################7            |  70%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##########6                           |  29%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##########################3           |  71%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##########8                           |  29%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ############################3         |  77%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #############################2        |  79%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###########                           |  30%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##############################1       |  82%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###########2                          |  30%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ###############################3      |  85%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###########5                          |  31%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ################################1     |  87%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | #################################3    |  90%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###########7                          |  32%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##################################2   |  93%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###########9                          |  32%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ###################################1  |  95%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ############1                         |  33%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ############3                         |  33%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ###################################9  |  97%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ############8                         |  35%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #############1                        |  35%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #############5                        |  37%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #############8                        |  37%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# transformers-4.24.0  | 4.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##############                        |  38%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##############3                       |  39%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##############6                       |  40%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###############                       |  41%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###############5                      |  42%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###############9                      |  43%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ################2                     |  44%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ################4                     |  44%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #################1                    |  46%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #################4                    |  47%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #################8                    |  48%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##################1                   |  49%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##################7                   |  51%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###################5                  |  53%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###################9                  |  54%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ####################3                 |  55%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ####################7                 |  56%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #####################                 |  57%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #####################4                |  58%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ######################                |  60%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ######################4               |  61%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ######################6               |  61%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #######################2              |  63%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #######################5              |  64%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #######################8              |  65%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ########################4             |  66%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ########################8             |  67%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #########################2            |  68%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #########################8            |  70%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##########################2           |  71%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##########################7           |  72%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###########################2          |  74%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###########################6          |  75%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ############################          |  76%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ############################4         |  77%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ############################7         |  78%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #############################3        |  79%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #############################6        |  80%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #############################9        |  81%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##############################6       |  83%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###############################       |  84%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###############################5      |  85%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###############################8      |  86%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ################################3     |  87%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ################################7     |  88%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #################################3    |  90%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | #################################7    |  91%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##################################3   |  93%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##################################7   |  94%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###################################2  |  95%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ###################################8  |  97%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ####################################2 |  98%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ####################################6 |  99%
#
#
#
#
#
#
# scipy-1.10.1         | 20.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: 7, not found
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda install -c conda-forge diffusers
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-arm64::urllib3==1.26.14=py310hca03da5_0
#   - pytorch-nightly/osx-arm64::torchvision==0.16.0.dev20230316=py310_cpu
#   - defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0
#   - pytorch-nightly/osx-arm64::torchaudio==2.0.0.dev20230317=py310_cpu
#   - defaults/osx-arm64::conda==23.1.0=py310hca03da5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/bergman/miniconda3
#
#   added / updated specs:
#     - diffusers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     diffusers-0.14.0           |     pyhd8ed1ab_0         245 KB  conda-forge
#     huggingface_hub-0.13.4     |     pyhd8ed1ab_0         141 KB  conda-forge
#     idna-3.4                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     requests-2.28.2            |     pyhd8ed1ab_1          56 KB  conda-forge
#     yaml-0.2.5                 |       h3422bc3_2          86 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         583 KB
#
# The following NEW packages will be INSTALLED:
#
#   diffusers          conda-forge/noarch::diffusers-0.14.0-pyhd8ed1ab_0
#   huggingface_hub    conda-forge/noarch::huggingface_hub-0.13.4-pyhd8ed1ab_0
#   idna               conda-forge/noarch::idna-3.4-pyhd8ed1ab_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.23.5-py310haf87e8b_0
#   pyyaml             pkgs/main/osx-arm64::pyyaml-6.0-py310h80987f9_1
#   regex              pkgs/main/osx-arm64::regex-2022.7.9-py310h1a28f6b_0
#   requests           conda-forge/noarch::requests-2.28.2-pyhd8ed1ab_1
#   typing-extensions  pkgs/main/osx-arm64::typing-extensions-4.4.0-py310hca03da5_0
#   yaml               conda-forge/osx-arm64::yaml-0.2.5-h3422bc3_2
#
#
#
# Downloading and Extracting Packages
# requests-2.28.2      | 56 KB     |                                       |   0%
# idna-3.4             | 55 KB     |                                       |   0%
#
# huggingface_hub-0.13 | 141 KB    |                                       |   0%
#
#
# diffusers-0.14.0     | 245 KB    |                                       |   0%
#
#
#
# requests-2.28.2      | 56 KB     | ##########6                           |  29%
#
#
#
# yaml-0.2.5           | 86 KB     | ######8                               |  19%
#
#
# diffusers-0.14.0     | 245 KB    | ##4                                   |   7%
#
# huggingface_hub-0.13 | 141 KB    | ####1                                 |  11%
# requests-2.28.2      | 56 KB     | ##################################### | 100%
# idna-3.4             | 55 KB     | ##################################### | 100%
#
#
#
# yaml-0.2.5           | 86 KB     | ##################################### | 100%
#
# huggingface_hub-0.13 | 141 KB    | ##################################### | 100%
#
#
# diffusers-0.14.0     | 245 KB    | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# 安装huggingface
# %conda install huggingface_hub
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-arm64::urllib3==1.26.14=py310hca03da5_0
#   - pytorch-nightly/osx-arm64::torchvision==0.16.0.dev20230316=py310_cpu
#   - defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0
#   - pytorch-nightly/osx-arm64::torchaudio==2.0.0.dev20230317=py310_cpu
#   - defaults/osx-arm64::conda==23.1.0=py310hca03da5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/bergman/miniconda3
#
#   added / updated specs:
#     - huggingface_hub
#
#
# The following NEW packages will be INSTALLED:
#
#   huggingface_hub    pkgs/main/osx-arm64::huggingface_hub-0.10.1-py310hca03da5_0
#   idna               pkgs/main/osx-arm64::idna-3.4-py310hca03da5_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.23.5-py310haf87e8b_0
#   pyyaml             pkgs/main/osx-arm64::pyyaml-6.0-py310h80987f9_1
#   requests           pkgs/main/osx-arm64::requests-2.28.1-py310hca03da5_1
#   typing-extensions  pkgs/main/osx-arm64::typing-extensions-4.4.0-py310hca03da5_0
#   yaml               pkgs/main/osx-arm64::yaml-0.2.5-h1a28f6b_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> pkgs/main::ca-certificates-2023.01.10-hca03da5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/osx-arm64::certifi-2022.12.7-py310hca03da5_0
#   openssl            conda-forge::openssl-1.1.1t-h03a7124_0 --> pkgs/main::openssl-1.1.1t-h1a28f6b_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda install ipywidgets
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-arm64::urllib3==1.26.14=py310hca03da5_0
#   - pytorch-nightly/osx-arm64::torchvision==0.16.0.dev20230316=py310_cpu
#   - defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0
#   - pytorch-nightly/osx-arm64::torchaudio==2.0.0.dev20230317=py310_cpu
#   - defaults/osx-arm64::conda==23.1.0=py310hca03da5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/bergman/miniconda3
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipywidgets-8.0.4           |  py310hca03da5_0         202 KB
#     jupyterlab_widgets-3.0.5   |  py310hca03da5_0         180 KB
#     widgetsnbextension-4.0.5   |  py310hca03da5_0         876 KB
#     ------------------------------------------------------------
#                                            Total:         1.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   idna               pkgs/main/osx-arm64::idna-3.4-py310hca03da5_0
#   ipywidgets         pkgs/main/osx-arm64::ipywidgets-8.0.4-py310hca03da5_0
#   jupyterlab_widgets pkgs/main/osx-arm64::jupyterlab_widgets-3.0.5-py310hca03da5_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.23.5-py310haf87e8b_0
#   requests           pkgs/main/osx-arm64::requests-2.28.1-py310hca03da5_1
#   widgetsnbextension pkgs/main/osx-arm64::widgetsnbextension-4.0.5-py310hca03da5_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> pkgs/main::ca-certificates-2023.01.10-hca03da5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/osx-arm64::certifi-2022.12.7-py310hca03da5_0
#   openssl            conda-forge::openssl-1.1.1t-h03a7124_0 --> pkgs/main::openssl-1.1.1t-h1a28f6b_0
#
#
#
# Downloading and Extracting Packages
# widgetsnbextension-4 | 876 KB    |                                       |   0%
# ipywidgets-8.0.4     | 202 KB    |                                       |   0%
#
# jupyterlab_widgets-3 | 180 KB    |                                       |   0%
#
# jupyterlab_widgets-3 | 180 KB    | ###2                                  |   9%
# widgetsnbextension-4 | 876 KB    | 6                                     |   2%
# widgetsnbextension-4 | 876 KB    | #####4                                |  15%
#
# jupyterlab_widgets-3 | 180 KB    | ####################################2 |  98%
#
# jupyterlab_widgets-3 | 180 KB    | ##################################### | 100%
#
#
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-arm64::urllib3==1.26.14=py310hca03da5_0
#   - pytorch-nightly/osx-arm64::torchvision==0.16.0.dev20230316=py310_cpu
#   - defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0
#   - pytorch-nightly/osx-arm64::torchaudio==2.0.0.dev20230317=py310_cpu
#   - defaults/osx-arm64::conda==23.1.0=py310hca03da5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/bergman/miniconda3
#
#   added / updated specs:
#     - conda
#
#
# The following NEW packages will be INSTALLED:
#
#   idna               pkgs/main/osx-arm64::idna-3.4-py310hca03da5_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.23.5-py310haf87e8b_0
#   requests           pkgs/main/osx-arm64::requests-2.28.1-py310hca03da5_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> pkgs/main::ca-certificates-2023.01.10-hca03da5_0
#   cryptography                       38.0.4-py310h834c97f_0 --> 39.0.1-py310h834c97f_0
#   flit-core          pkgs/main/noarch::flit-core-3.6.0-pyh~ --> pkgs/main/osx-arm64::flit-core-3.8.0-py310hca03da5_0
#   gettext                                 0.21.0-h826f4ad_0 --> 0.21.0-h13f89a0_1
#   jupyter_core                        5.2.0-py310hca03da5_0 --> 5.3.0-py310hca03da5_0
#   libtasn1                                4.16.0-h1a28f6b_0 --> 4.19.0-h80987f9_0
#   libxml2                                 2.9.14-h8c5e841_0 --> 2.10.3-h372ba2a_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-22.0.0-py~ --> pkgs/main/osx-arm64::pyopenssl-23.0.0-py310hca03da5_0
#   sqlite                                  3.40.1-h7a7dc30_0 --> 3.41.1-h80987f9_0
#   tqdm                               4.64.1-py310hca03da5_0 --> 4.65.0-py310h33ce5c2_0
#   tzdata                                   2022g-h04d1e81_0 --> 2023c-h04d1e81_0
#   zstandard                          0.18.0-py310h1a28f6b_0 --> 0.19.0-py310h80987f9_0
#   zstd                                     1.5.2-h8574219_0 --> 1.5.4-hd90d995_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/osx-arm64::certifi-2022.12.7-py310hca03da5_0
#   jupyter_client     conda-forge/noarch::jupyter_client-8.~ --> pkgs/main/osx-arm64::jupyter_client-8.1.0-py310hca03da5_0
#   libsodium          conda-forge::libsodium-1.0.18-h27ca64~ --> pkgs/main::libsodium-1.0.18-h1a28f6b_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.5.~ --> pkgs/main/osx-arm64::nest-asyncio-1.5.6-py310hca03da5_0
#   openssl            conda-forge::openssl-1.1.1t-h03a7124_0 --> pkgs/main::openssl-1.1.1t-h1a28f6b_0
#   packaging          conda-forge/noarch::packaging-23.0-py~ --> pkgs/main/osx-arm64::packaging-23.0-py310hca03da5_0
#   python-dateutil    conda-forge::python-dateutil-2.8.2-py~ --> pkgs/main::python-dateutil-2.8.2-pyhd3eb1b0_0
#   zeromq               conda-forge::zeromq-4.3.4-hbdafb3b_1 --> pkgs/main::zeromq-4.3.4-hc377ac9_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from huggingface_hub import login

login(token=os.environ.get("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"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/lib/python3.10/site-packages/huggingface_hub/_login.py:185, in notebook_login()
#     184 try:
# --> 185     import ipywidgets.widgets as widgets  # type: ignore
#     186     from IPython.display import clear_output, display  # type: ignore
#
# ModuleNotFoundError: No module named 'ipywidgets'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 4
#       1 import os
#       2 from huggingface_hub import login
# ----> 4 login(token=os.environ.get("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"))
#
# File ~/miniconda3/lib/python3.10/site-packages/huggingface_hub/_login.py:90, in login(token, add_to_git_credential)
#      88     _login(token, add_to_git_credential=add_to_git_credential)
#      89 elif is_notebook():
# ---> 90     notebook_login()
#      91 else:
#      92     interpreter_login()
#
# File ~/miniconda3/lib/python3.10/site-packages/huggingface_hub/_login.py:188, in notebook_login()
#     186     from IPython.display import clear_output, display  # type: ignore
#     187 except ImportError:
# --> 188     raise ImportError(
#     189         "The `notebook_login` function can only be used in a notebook (Jupyter or"
#     190         " Colab) and you need the `ipywidgets` module: `pip install ipywidgets`."
#     191     )
#     193 box_layout = widgets.Layout(display="flex", flex_flow="column", align_items="center", width="50%")
#     195 token_widget = widgets.Password(description="Token:")
#
# ImportError: The `notebook_login` function can only be used in a notebook (Jupyter or Colab) and you need the `ipywidgets` module: `pip install ipywidgets`.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/lib/python3.10/site-packages/huggingface_hub/_login.py:185, in notebook_login()
#     184 try:
# --> 185     import ipywidgets.widgets as widgets  # type: ignore
#     186     from IPython.display import clear_output, display  # type: ignore
#
# ModuleNotFoundError: No module named 'ipywidgets'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from huggingface_hub import notebook_login
# ----> 2 notebook_login()
#
# File ~/miniconda3/lib/python3.10/site-packages/huggingface_hub/_login.py:188, in notebook_login()
#     186     from IPython.display import clear_output, display  # type: ignore
#     187 except ImportError:
# --> 188     raise ImportError(
#     189         "The `notebook_login` function can only be used in a notebook (Jupyter or"
#     190         " Colab) and you need the `ipywidgets` module: `pip install ipywidgets`."
#     191     )
#     193 box_layout = widgets.Layout(display="flex", flex_flow="column", align_items="center", width="50%")
#     195 token_widget = widgets.Password(description="Token:")
#
# ImportError: The `notebook_login` function can only be used in a notebook (Jupyter or Colab) and you need the `ipywidgets` module: `pip install ipywidgets`.

# %%
# make sure you're logged in with `huggingface-cli login`
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe = pipe.to("mps")

# Recommended if your computer has < 64 GB of RAM
pipe.enable_attention_slicing()

prompt = "a photo of an astronaut riding a horse on mars"

# First-time "warmup" pass (see explanation above)
_ = pipe(prompt, num_inference_steps=1)

# Results match those from the CPU device after the warmup pass.
image = pipe(prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 # make sure you're logged in with `huggingface-cli login`
# ----> 2 from diffusers import StableDiffusionPipeline
#       4 pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
#       5 pipe = pipe.to("mps")
#
# File ~/miniconda3/lib/python3.10/site-packages/diffusers/__init__.py:27
#      25     from .utils.dummy_onnx_objects import *  # noqa F403
#      26 else:
# ---> 27     from .pipelines import OnnxRuntimeModel
#      29 try:
#      30     if not is_torch_available():
#
# File ~/miniconda3/lib/python3.10/site-packages/diffusers/pipelines/__init__.py:18
#      16     from ..utils.dummy_pt_objects import *  # noqa F403
#      17 else:
# ---> 18     from .dance_diffusion import DanceDiffusionPipeline
#      19     from .ddim import DDIMPipeline
#      20     from .ddpm import DDPMPipeline
#
# File ~/miniconda3/lib/python3.10/site-packages/diffusers/pipelines/dance_diffusion/__init__.py:1
# ----> 1 from .pipeline_dance_diffusion import DanceDiffusionPipeline
#
# File ~/miniconda3/lib/python3.10/site-packages/diffusers/pipelines/dance_diffusion/pipeline_dance_diffusion.py:21
#      18 import torch
#      20 from ...utils import logging, randn_tensor
# ---> 21 from ..pipeline_utils import AudioPipelineOutput, DiffusionPipeline
#      24 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#      27 class DanceDiffusionPipeline(DiffusionPipeline):
#
# File ~/miniconda3/lib/python3.10/site-packages/diffusers/pipelines/pipeline_utils.py:61
#      40 from ..utils import (
#      41     CONFIG_NAME,
#      42     DEPRECATED_REVISION_ARGS,
#    (...)
#      56     logging,
#      57 )
#      60 if is_transformers_available():
# ---> 61     import transformers
#      62     from transformers import PreTrainedModel
#      63     from transformers.utils import FLAX_WEIGHTS_NAME as TRANSFORMERS_FLAX_WEIGHTS_NAME
#
# File ~/miniconda3/lib/python3.10/site-packages/transformers/__init__.py:30
#      27 from typing import TYPE_CHECKING
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)
#      43     logging,
#      44 )
#      47 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File ~/miniconda3/lib/python3.10/site-packages/transformers/dependency_versions_check.py:41
#      38         if not is_tokenizers_available():
#      39             continue  # not required, check version only if installed
# ---> 41     require_version_core(deps[pkg])
#      42 else:
#      43     raise ValueError(f"can't find {pkg} in {deps.keys()}, check dependency_versions_table.py")
#
# File ~/miniconda3/lib/python3.10/site-packages/transformers/utils/versions.py:120, in require_version_core(requirement)
#     118 """require_version wrapper which emits a core-specific hint on failure"""
#     119 hint = "Try: pip install transformers -U or pip install -e '.[dev]' if you're working with git main"
# --> 120 return require_version(requirement, hint)
#
# File ~/miniconda3/lib/python3.10/site-packages/transformers/utils/versions.py:114, in require_version(requirement, hint)
#     112 if want_ver is not None:
#     113     for op, want_ver in wanted.items():
# --> 114         _compare_versions(op, got_ver, want_ver, requirement, pkg, hint)
#
# File ~/miniconda3/lib/python3.10/site-packages/transformers/utils/versions.py:49, in _compare_versions(op, got_ver, want_ver, requirement, pkg, hint)
#      47     raise ValueError("want_ver is None")
#      48 if not ops[op](version.parse(got_ver), version.parse(want_ver)):
# ---> 49     raise ImportError(
#      50         f"{requirement} is required for a normal functioning of this module, but found {pkg}=={got_ver}.{hint}"
#      51     )
#
# ImportError: tokenizers>=0.11.1,!=0.11.3,<0.13 is required for a normal functioning of this module, but found tokenizers==0.13.2.
# Try: pip install transformers -U or pip install -e '.[dev]' if you're working with git main
